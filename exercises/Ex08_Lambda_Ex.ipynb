# %% [markdown]
# <a href="https://colab.research.google.com/github/MasujiOno/MMDT_T-PY101_Batch03/blob/main/exercises/Ex08_Lambda_Ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1). Write a lambda function that takes an integer 'year' and returns 'age'.

# %%
from datetime import datetime

current_year = datetime.now().year

get_age = lambda year: current_year - year

print(get_age(1990))
# Out:
# 36

# %% [markdown]
# Q2) Write a lambda function that takes a float "cost" and returns a float "price" by adding 10% to the cost.

# %%
calculate_price = lambda cost: cost * 1.10
cost_amount = float(input("Enter cost:"))
total_price = calculate_price(cost_amount)
print(f"Price: {total_price}")
# Out:
# Enter cost:451.89
# Price: 497.079

# %% [markdown]
# Q3) Write a lambda function that takes two strings 'name' , 'domain' and returns an email address (string).

# %%
create_email = lambda name, domain: f"{name.lower().replace(' ', '.')}@{domain.lower()}"

user_name = input("Enter username: ")
user_domain = input("Enter domain name: ")

email_address = create_email(user_name, user_domain)
print(email_address)
# Out:
# Enter username: masujiono
# Enter domain name: gmail.com
# masujiono@gmail.com

# %% [markdown]
# Q4) Lambda in Data Science/Data Analysis

# %%
import pandas as pd

df = pd.read_csv("./data/rentals.csv")

# Q4.1) Create a new column called "size" where each entry is
# determined by the number of bathrooms: 'large' if the number of bathrooms is greater than 3, and 'small' otherwise.

df['size'] = df['bathrooms'].apply(lambda x: 'large' if x > 3 else 'small')
print(df[['bathrooms', 'size']].head())



# -----------------------------------------------------------------#
# Q4.2) Creat a new column called "price_category" where
# Assign each entry as the following categories based on the price:
# If the price is greater than 100, the category should be 'premium'.
# Otherwise, the category should be 'standard'.

df['price_category'] = df['price'].apply(lambda x: 'premium' if x > 100 else 'standard')
print(df['price_category'].value_counts())



# -----------------------------------------------------------------#
# Do not change the code below:
# Print the first five rows to see the data. You should have 11 columns

print(f"DataFrame has {df.shape[1]} columns")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2861149006.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("./data/rentals.csv")
#       4
#       5 # Q4.1) Create a new column called "size" where each entry is
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/rentals.csv'
